# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Car Fuel and Emissions 2000-2013.csv', low_memory = False)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                      file  year manufacturer      model         description  \
# 0  DatapartC_july2000.csv  2000   Alfa Romeo  145 Range  1.6 Twin Spark 16v
# 1  DatapartC_july2000.csv  2000   Alfa Romeo  145 Range  1.8 Twin Spark 16v
# 2  DatapartC_july2000.csv  2000   Alfa Romeo  145 Range          Cloverleaf
# 3  DatapartC_july2000.csv  2000   Alfa Romeo  146 Range  1.6 Twin Spark 16v
# 4  DatapartC_july2000.csv  2000   Alfa Romeo  146 Range  1.8 Twin Spark 16v
#
#    euro_standard tax_band transmission transmission_type  engine_capacity  \
# 0              2      NaN           M5            Manual           1598.0
# 1              2      NaN           M5            Manual           1747.0
# 2              2      NaN           M5            Manual           1970.0
# 3              2      NaN           M5            Manual           1598.0
# 4              2      NaN           M5            Manual           1747.0
#
# ...

# %%
df.columns
# Out:
# Index(['file', 'year', 'manufacturer', 'model', 'description', 'euro_standard',
#        'tax_band', 'transmission', 'transmission_type', 'engine_capacity',
#        'fuel_type', 'urban_metric', 'extra_urban_metric', 'combined_metric',
#        'urban_imperial', 'extra_urban_imperial', 'combined_imperial',
#        'noise_level', 'co2', 'thc_emissions', 'co_emissions', 'nox_emissions',
#        'thc_nox_emissions', 'particulates_emissions', 'fuel_cost_12000_miles',
#        'fuel_cost_6000_miles', 'standard_12_months', 'standard_6_months',
#        'first_year_12_months', 'first_year_6_months', 'date_of_change'],
#       dtype='object')

# %%
df1 = df[['year', 'manufacturer', 'model',
       'transmission_type', 'engine_capacity',
       'fuel_type',
        'co2', 'co_emissions', 'nox_emissions' 
       ]]

# %%
df1
# Out:
#        year manufacturer          model transmission_type  engine_capacity  \
# 0      2000   Alfa Romeo      145 Range            Manual           1598.0
# 1      2000   Alfa Romeo      145 Range            Manual           1747.0
# 2      2000   Alfa Romeo      145 Range            Manual           1970.0
# 3      2000   Alfa Romeo      146 Range            Manual           1598.0
# 4      2000   Alfa Romeo      146 Range            Manual           1747.0
# ...     ...          ...            ...               ...              ...
# 45506  2013   Volkswagen  New Golf 2013               NaN           1968.0
# 45507  2013   Volkswagen  New Golf 2013               NaN           1984.0
# 45508  2013   Volkswagen  New Golf 2013               NaN           1984.0
# 45509  2013   Volkswagen  New Golf 2013               NaN           1984.0
# 45510  2013   Volkswagen  New Golf 2013               NaN           1984.0
#
#       fuel_type  co2  co_emissions  nox_emissions
# ...

# %%
df1.isna().sum()
# Out:
# year                    0
# manufacturer            0
# model                   0
# transmission_type     341
# engine_capacity         7
# fuel_type               0
# co2                     0
# co_emissions          319
# nox_emissions        5361
# dtype: int64

# %%
#df1[df1['thc_emissions'].isna()]

# %%
df1.describe()
# Out:
#                year  engine_capacity           co2  co_emissions  \
# count  45511.000000     45504.000000  45511.000000  45192.000000
# mean    2007.316055      2182.770526    189.592846    375.084962
# std        3.832559       899.100669     56.993217   1048.920760
# min     2000.000000       209.000000      0.000000   -200.000000
# 25%     2004.000000      1598.000000    150.000000    188.800000
# 50%     2008.000000      1988.000000    180.000000    302.000000
# 75%     2011.000000      2429.000000    218.000000    480.000000
# max     2013.000000      8285.000000    590.000000  75000.000000
#
#        nox_emissions
# count   40150.000000
# mean      127.164387
# std      1189.748216
# min         0.250000
# 25%        24.000000
# 50%        56.000000
# 75%       179.000000
# max    237000.000000

# %%
df1.hist(bins = 60, figsize = (20,10))
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'engine_capacity'}>],
#        [<Axes: title={'center': 'co2'}>,
#         <Axes: title={'center': 'co_emissions'}>],
#        [<Axes: title={'center': 'nox_emissions'}>, <Axes: >]],
#       dtype=object)

# %%
df1[df1['nox_emissions'] < 1000]
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013               NaN
# 45507  2013   Volkswagen                      New Golf 2013               NaN
# 45508  2013   Volkswagen                      New Golf 2013               NaN
# 45509  2013   Volkswagen                      New Golf 2013               NaN
# 45510  2013   Volkswagen                      New Golf 2013               NaN
#
# ...

# %%
sns.boxplot(data=df1, x='nox_emissions')
plt.show()

# %%
upper_limit = df1['nox_emissions'].mean() + 3*df1['nox_emissions'].std()
lower_limit = df1['nox_emissions'].mean() - 3*df1['nox_emissions'].std()
print(upper_limit)
print(lower_limit)
# Out:
# 3696.409033592044
# -3442.0802597439747

# %%
df1.loc[(df1['nox_emissions'] > upper_limit) | (df1['nox_emissions'] < lower_limit)]
# Out:
#        year manufacturer          model transmission_type  engine_capacity  \
# 29030  2009     Vauxhall  Signum MY2008         Automatic           2959.0
#
#       fuel_type  co2  co_emissions  nox_emissions
# 29030    Diesel  194         102.0       237000.0

# %%
new_df1 = df1.loc[(df1['nox_emissions'] < upper_limit) & (df1['nox_emissions'] > lower_limit)]

# %%
print(len(new_df1))
print(len(df1))
# Out:
# 40149
# 45511

# %%
new_df1[new_df1['nox_emissions'] > 1000]
# Out:
#       year   manufacturer                                model  \
# 199   2000  Chrysler Jeep  Jeep Grand Cherokee (00 Model Year)
# 2009  2001  Chrysler Jeep  Jeep Grand Cherokee (01 Model Year)
#
#      transmission_type  engine_capacity fuel_type  co2  co_emissions  \
# 199          Automatic           3124.0    Diesel  308          42.0
# 2009         Automatic           3124.0    Diesel  308          42.0
#
#       nox_emissions
# 199          1013.0
# 2009         1013.0

# %%
sns.boxplot(data=new_df1, x='nox_emissions')
plt.show()

# %%
print(new_df1.columns)
# Out:
# Index(['year', 'manufacturer', 'model', 'transmission_type', 'engine_capacity',
#        'fuel_type', 'co2', 'co_emissions', 'nox_emissions'],
#       dtype='object')

# %%
new_df1['manufacturer'].value_counts().plot(kind = 'bar', figsize = (20,10))
# Out:
# <Axes: xlabel='manufacturer'>

# %%
sns.boxplot(data=new_df1, x='engine_capacity')
plt.show()

# %%
upper_limit = new_df1['engine_capacity'].mean() + 3*new_df1['engine_capacity'].std()
lower_limit = new_df1['engine_capacity'].mean() - 3*new_df1['engine_capacity'].std()
print(upper_limit)
print(lower_limit)
# Out:
# 4826.0845717949605
# -468.77156275363905

# %%
new_df1.loc[(new_df1['engine_capacity'] > upper_limit) | (new_df1['engine_capacity'] < lower_limit)]
# Out:
#        year   manufacturer                           model transmission_type  \
# 167    2000            BMW                    5 Series E39            Manual
# 172    2000            BMW                    7 Series E38         Automatic
# 173    2000            BMW                    7 Series E38         Automatic
# 175    2000            BMW                   Z8 Series E52            Manual
# 1160   2000    Rolls-Royce                         Bentley         Automatic
# ...     ...            ...                             ...               ...
# 45446  2013  Mercedes-Benz       CLS-Class Model Year 2014               NaN
# 45450  2013  Mercedes-Benz  E-Class Estate Model Year 2014               NaN
# 45454  2013  Mercedes-Benz  E-Class Saloon Model Year 2014               NaN
# 45495  2013    Rolls-Royce                           Ghost               NaN
# 45496  2013    Rolls-Royce                           Ghost               NaN
#
# ...

# %%
df2 = new_df1.loc[(new_df1['engine_capacity'] < upper_limit) & (new_df1['engine_capacity'] > lower_limit)]

# %%
df2
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013               NaN
# 45507  2013   Volkswagen                      New Golf 2013               NaN
# 45508  2013   Volkswagen                      New Golf 2013               NaN
# 45509  2013   Volkswagen                      New Golf 2013               NaN
# 45510  2013   Volkswagen                      New Golf 2013               NaN
#
# ...

# %%
print(len(new_df1))
print(len(df2))
# Out:
# 40149
# 39079

# %%
sns.boxplot(data=df2, x='engine_capacity')
plt.show()

# %%
sns.boxplot(data=df2, x='co2')
plt.show()

# %%
upper_limit = df2['co2'].mean() + 3*df2['co2'].std()
lower_limit = df2['co2'].mean() - 3*df2['co2'].std()
print(upper_limit)
print(lower_limit)
# Out:
# 327.25620344873965
# 36.230733269190694

# %%
df2.loc[(df2['co2'] > upper_limit) | (df2['co2'] < lower_limit)]
# Out:
#        year   manufacturer                                model  \
# 174    2000            BMW                        X5 Series E53
# 198    2000  Chrysler Jeep        Jeep Cherokee (00 Model Year)
# 200    2000  Chrysler Jeep  Jeep Grand Cherokee (00 Model Year)
# 201    2000  Chrysler Jeep  Jeep Grand Cherokee (00 Model Year)
# 1049   2000        Porsche                           All Models
# ...     ...            ...                                  ...
# 42830  2013       Maserati                          Granturismo
# 42831  2013       Maserati                          Granturismo
# 44209  2013       Vauxhall              Ampera, Model Year 2012
# 44210  2013       Vauxhall              Ampera, Model Year 2012
# 44211  2013       Vauxhall              Ampera, Model Year 2012
#
#       transmission_type  engine_capacity           fuel_type  co2  \
# 174           Automatic           4398.0              Petrol  335
# ...

# %%
df3 = df2.loc[(df2['co2'] < upper_limit) & (df2['co2'] > lower_limit)]

# %%
df3
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013               NaN
# 45507  2013   Volkswagen                      New Golf 2013               NaN
# 45508  2013   Volkswagen                      New Golf 2013               NaN
# 45509  2013   Volkswagen                      New Golf 2013               NaN
# 45510  2013   Volkswagen                      New Golf 2013               NaN
#
# ...

# %%
print(len(df2))
print(len(df3))
# Out:
# 39079
# 38686

# %%
sns.boxplot(data=df3, x='co2')
plt.show()

# %%
q1 = df3['co_emissions'].quantile(0.25)
q3 = df3['co_emissions'].quantile(0.75)
iqr = q3 - q1

# %%
q1, q3, iqr
# Out:
# (173.0, 436.0, 263.0)

# %%
upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (-221.5, 830.5)

# %%
df3.loc[(df3['co_emissions'] > upper_limit) | (df3['co_emissions'] < lower_limit)]
# Out:
#        year manufacturer                               model  \
# 98     2000          BMW                        3 Series E36
# 104    2000          BMW                        3 Series E36
# 107    2000          BMW                        3 Series E36
# 113    2000          BMW                        3 Series E46
# 115    2000          BMW                        3 Series E46
# ...     ...          ...                                 ...
# 44094  2013       Suzuki                              Splash
# 44095  2013       Suzuki                              Splash
# 44204  2013     Vauxhall              Agila, Model Year 2011
# 44208  2013     Vauxhall              Agila, Model Year 2012
# 44216  2013     Vauxhall  Antara 5 Door SUV, Model Year 2012
#
#       transmission_type  engine_capacity fuel_type  co2  co_emissions  \
# 98            Automatic           1895.0    Petrol  213        1058.0
# 104              Manual           1895.0    Petrol  187        1160.0
# ...

# %%
df4 = df3.loc[(df3['co_emissions'] < upper_limit) & (df3['co_emissions'] > lower_limit)]

# %%
df4
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013               NaN
# 45507  2013   Volkswagen                      New Golf 2013               NaN
# 45508  2013   Volkswagen                      New Golf 2013               NaN
# 45509  2013   Volkswagen                      New Golf 2013               NaN
# 45510  2013   Volkswagen                      New Golf 2013               NaN
#
# ...

# %%
print(len(df3))
print(len(df4))
# Out:
# 38686
# 37246

# %%
sns.boxplot(data=df3, x='co_emissions')
plt.show()

# %%
sns.boxplot(data=df4, x='co_emissions')
plt.show()

# %%
df4.hist(bins = 60, figsize = (20,10))
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'engine_capacity'}>],
#        [<Axes: title={'center': 'co2'}>,
#         <Axes: title={'center': 'co_emissions'}>],
#        [<Axes: title={'center': 'nox_emissions'}>, <Axes: >]],
#       dtype=object)

# %%
df4
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013               NaN
# 45507  2013   Volkswagen                      New Golf 2013               NaN
# 45508  2013   Volkswagen                      New Golf 2013               NaN
# 45509  2013   Volkswagen                      New Golf 2013               NaN
# 45510  2013   Volkswagen                      New Golf 2013               NaN
#
# ...

# %%
df
# Out:
#                                         file  year manufacturer  \
# 0                     DatapartC_july2000.csv  2000   Alfa Romeo
# 1                     DatapartC_july2000.csv  2000   Alfa Romeo
# 2                     DatapartC_july2000.csv  2000   Alfa Romeo
# 3                     DatapartC_july2000.csv  2000   Alfa Romeo
# 4                     DatapartC_july2000.csv  2000   Alfa Romeo
# ...                                      ...   ...          ...
# 45506  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45507  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45508  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45509  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45510  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
#
#                model                       description  euro_standard  \
# 0          145 Range                1.6 Twin Spark 16v              2
# ...

# %%
df4
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013               NaN
# 45507  2013   Volkswagen                      New Golf 2013               NaN
# 45508  2013   Volkswagen                      New Golf 2013               NaN
# 45509  2013   Volkswagen                      New Golf 2013               NaN
# 45510  2013   Volkswagen                      New Golf 2013               NaN
#
# ...

# %%
df.hist(bins = 60, figsize = (20,10))
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'euro_standard'}>,
#         <Axes: title={'center': 'engine_capacity'}>,
#         <Axes: title={'center': 'urban_metric'}>,
#         <Axes: title={'center': 'extra_urban_metric'}>],
#        [<Axes: title={'center': 'combined_metric'}>,
#         <Axes: title={'center': 'urban_imperial'}>,
#         <Axes: title={'center': 'extra_urban_imperial'}>,
#         <Axes: title={'center': 'combined_imperial'}>,
#         <Axes: title={'center': 'noise_level'}>],
#        [<Axes: title={'center': 'co2'}>,
#         <Axes: title={'center': 'thc_emissions'}>,
#         <Axes: title={'center': 'co_emissions'}>,
#         <Axes: title={'center': 'nox_emissions'}>,
#         <Axes: title={'center': 'thc_nox_emissions'}>],
#        [<Axes: title={'center': 'particulates_emissions'}>,
#         <Axes: title={'center': 'fuel_cost_12000_miles'}>,
#         <Axes: title={'center': 'fuel_cost_6000_miles'}>,
# ...

# %%
df4.hist(bins = 60, figsize = (20,10))
# Out:
# array([[<Axes: title={'center': 'year'}>,
#         <Axes: title={'center': 'engine_capacity'}>],
#        [<Axes: title={'center': 'co2'}>,
#         <Axes: title={'center': 'co_emissions'}>],
#        [<Axes: title={'center': 'nox_emissions'}>, <Axes: >]],
#       dtype=object)

# %%
df4
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013               NaN
# 45507  2013   Volkswagen                      New Golf 2013               NaN
# 45508  2013   Volkswagen                      New Golf 2013               NaN
# 45509  2013   Volkswagen                      New Golf 2013               NaN
# 45510  2013   Volkswagen                      New Golf 2013               NaN
#
# ...

# %%
df4.isna().sum()
# Out:
# year                   0
# manufacturer           0
# model                  0
# transmission_type    325
# engine_capacity        0
# fuel_type              0
# co2                    0
# co_emissions           0
# nox_emissions          0
# dtype: int64

# %%
df4.isnull().sum()
# Out:
# year                   0
# manufacturer           0
# model                  0
# transmission_type    325
# engine_capacity        0
# fuel_type              0
# co2                    0
# co_emissions           0
# nox_emissions          0
# dtype: int64

# %%
df4['transmission_type'].fillna(df['transmission_type'].mode()[0], inplace=True)
# Out:
# C:\Users\zunai\AppData\Local\Temp\ipykernel_2684\1714473350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['transmission_type'].fillna(df['transmission_type'].mode()[0], inplace=True)

# %%
df4.isnull().sum()
# Out:
# year                 0
# manufacturer         0
# model                0
# transmission_type    0
# engine_capacity      0
# fuel_type            0
# co2                  0
# co_emissions         0
# nox_emissions        0
# dtype: int64

# %%
df4
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013            Manual
# 45507  2013   Volkswagen                      New Golf 2013            Manual
# 45508  2013   Volkswagen                      New Golf 2013            Manual
# 45509  2013   Volkswagen                      New Golf 2013            Manual
# 45510  2013   Volkswagen                      New Golf 2013            Manual
#
# ...

# %%
 df4.describe()
# Out:
#                year  engine_capacity           co2  co_emissions  \
# count  37246.000000     37246.000000  37246.000000  37246.000000
# mean    2008.148768      2060.423052    178.676341    306.360119
# std        3.483820       640.596253     44.819550    183.684309
# min     2000.000000       209.000000     48.000000   -200.000000
# 25%     2006.000000      1598.000000    146.000000    170.000000
# 50%     2009.000000      1984.000000    172.000000    275.000000
# 75%     2011.000000      2204.000000    206.000000    415.000000
# max     2013.000000      4806.000000    327.000000    830.000000
#
#        nox_emissions
# count   37246.000000
# mean      124.574519
# std       134.925519
# min         0.250000
# 25%        24.000000
# 50%        60.000000
# 75%       187.000000
# max      1013.000000

# %%
df4.manufacturer.unique().sum()
# Out:
# 'AudiBMWChrysler JeepCitroenFordHondaHyundaiLexusMercedes-BenzMetrocabNissanPeugeotPorscheRenaultRover Group LimitedSaabSeatSkodaSuzukiToyotaVauxhallVolkswagenVolvoAlfa RomeoDaewoo CarsDaihatsuFiatJaguar CarsKiaLand RoverLotusMazdaMG Rover GroupMicro Compact CarMiniMitsubishiPeroduaProtonSubaruChevroletIsuzuLTIMorgan Motor CompanyTataSmartSsangYongCadillacDodgeHummerAbarthAston Martin LagondaFerrariInfinitiMG Motors UkBentley MotorsMcLarenDaciaMaseratiMG Motors UK'

# %%
df
# Out:
#                                         file  year manufacturer  \
# 0                     DatapartC_july2000.csv  2000   Alfa Romeo
# 1                     DatapartC_july2000.csv  2000   Alfa Romeo
# 2                     DatapartC_july2000.csv  2000   Alfa Romeo
# 3                     DatapartC_july2000.csv  2000   Alfa Romeo
# 4                     DatapartC_july2000.csv  2000   Alfa Romeo
# ...                                      ...   ...          ...
# 45506  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45507  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45508  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45509  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45510  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
#
#                model                       description  euro_standard  \
# 0          145 Range                1.6 Twin Spark 16v              2
# ...

# %%
df4
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013            Manual
# 45507  2013   Volkswagen                      New Golf 2013            Manual
# 45508  2013   Volkswagen                      New Golf 2013            Manual
# 45509  2013   Volkswagen                      New Golf 2013            Manual
# 45510  2013   Volkswagen                      New Golf 2013            Manual
#
# ...

# %%
df4['fuel_type'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'Petrol Hybrid', 'CNG',
#        'Petrol Electric', 'LPG / Petrol', 'Petrol / E85 (Flex Fuel)',
#        'Petrol / E85', 'Diesel Electric', 'Electricity/Petrol',
#        'Electricity/Diesel'], dtype=object)

# %%
df4['transmission_type'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df4['manufacturer'].unique()
# Out:
# array(['Audi', 'BMW', 'Chrysler Jeep', 'Citroen', 'Ford', 'Honda',
#        'Hyundai', 'Lexus', 'Mercedes-Benz', 'Metrocab', 'Nissan',
#        'Peugeot', 'Porsche', 'Renault', 'Rover Group Limited', 'Saab',
#        'Seat', 'Skoda', 'Suzuki', 'Toyota', 'Vauxhall', 'Volkswagen',
#        'Volvo', 'Alfa Romeo', 'Daewoo Cars', 'Daihatsu', 'Fiat',
#        'Jaguar Cars', 'Kia', 'Land Rover', 'Lotus', 'Mazda',
#        'MG Rover Group', 'Micro Compact Car', 'Mini', 'Mitsubishi',
#        'Perodua', 'Proton', 'Subaru', 'Chevrolet', 'Isuzu', 'LTI',
#        'Morgan Motor Company', 'Tata', 'Smart', 'SsangYong', 'Cadillac',
#        'Dodge', 'Hummer', 'Abarth', 'Aston Martin Lagonda', 'Ferrari',
#        'Infiniti', 'MG Motors Uk', 'Bentley Motors', 'McLaren', 'Dacia',
#        'Maserati', 'MG Motors UK'], dtype=object)

# %%
dummies = pd.get_dummies(df4['transmission_type'], dtype = int)

# %%
dummies
# Out:
#        Automatic  Manual
# 65             0       1
# 66             1       0
# 82             0       1
# 83             1       0
# 97             0       1
# ...          ...     ...
# 45506          0       1
# 45507          0       1
# 45508          0       1
# 45509          0       1
# 45510          0       1
#
# [37246 rows x 2 columns]

# %%
merged = pd.concat([df4, dummies], axis = 1)

# %%
df5 = merged.drop(['transmission_type','Automatic'], axis = 1)

# %%
merged
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013            Manual
# 45507  2013   Volkswagen                      New Golf 2013            Manual
# 45508  2013   Volkswagen                      New Golf 2013            Manual
# 45509  2013   Volkswagen                      New Golf 2013            Manual
# 45510  2013   Volkswagen                      New Golf 2013            Manual
#
# ...

# %%
dummies1 = pd.get_dummies(df4['fuel_type'], dtype = int)

# %%
df5
# Out:
#        year manufacturer                              model  engine_capacity  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)           1896.0
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)           1896.0
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)           2496.0
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)           2496.0
# 97     2000          BMW                       3 Series E36           1895.0
# ...     ...          ...                                ...              ...
# 45506  2013   Volkswagen                      New Golf 2013           1968.0
# 45507  2013   Volkswagen                      New Golf 2013           1984.0
# 45508  2013   Volkswagen                      New Golf 2013           1984.0
# 45509  2013   Volkswagen                      New Golf 2013           1984.0
# 45510  2013   Volkswagen                      New Golf 2013           1984.0
#
# ...

# %%
dummies1
# Out:
#        CNG  Diesel  Diesel Electric  Electricity/Diesel  Electricity/Petrol  \
# 65       0       1                0                   0                   0
# 66       0       1                0                   0                   0
# 82       0       1                0                   0                   0
# 83       0       1                0                   0                   0
# 97       0       0                0                   0                   0
# ...    ...     ...              ...                 ...                 ...
# 45506    0       1                0                   0                   0
# 45507    0       0                0                   0                   0
# 45508    0       0                0                   0                   0
# 45509    0       0                0                   0                   0
# 45510    0       0                0                   0                   0
#
# ...

# %%
merged = pd.concat([df4, dummies1], axis = 1)

# %%
df4 = merged.drop(['fuel_type','CNG'], axis = 1)

# %%
df4
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013            Manual
# 45507  2013   Volkswagen                      New Golf 2013            Manual
# 45508  2013   Volkswagen                      New Golf 2013            Manual
# 45509  2013   Volkswagen                      New Golf 2013            Manual
# 45510  2013   Volkswagen                      New Golf 2013            Manual
#
# ...

# %%
df5
# Out:
#        year manufacturer                              model  engine_capacity  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)           1896.0
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)           1896.0
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)           2496.0
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)           2496.0
# 97     2000          BMW                       3 Series E36           1895.0
# ...     ...          ...                                ...              ...
# 45506  2013   Volkswagen                      New Golf 2013           1968.0
# 45507  2013   Volkswagen                      New Golf 2013           1984.0
# 45508  2013   Volkswagen                      New Golf 2013           1984.0
# 45509  2013   Volkswagen                      New Golf 2013           1984.0
# 45510  2013   Volkswagen                      New Golf 2013           1984.0
#
# ...

# %%
df4
# Out:
#        year manufacturer                              model transmission_type  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97     2000          BMW                       3 Series E36            Manual
# ...     ...          ...                                ...               ...
# 45506  2013   Volkswagen                      New Golf 2013            Manual
# 45507  2013   Volkswagen                      New Golf 2013            Manual
# 45508  2013   Volkswagen                      New Golf 2013            Manual
# 45509  2013   Volkswagen                      New Golf 2013            Manual
# 45510  2013   Volkswagen                      New Golf 2013            Manual
#
# ...

# %%
df4 = merged.drop(['transmission_type','Automatic'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df4 = merged.drop(['transmission_type','Automatic'], axis = 1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %%
frequency = df4['manufacturer'].value_counts()

threshold = 50

low_frequency_categories = frequency[frequency < threshold].index

df['manufacturer'] = df4['manufacturer'].replace(low_frequency_categories, 'Other')

# %%
df_encoded = pd.get_dummies(df4, columns=['manufacturer'], dtype = int)

# %%
df4.manufacturer.value_counts()
# Out:
# manufacturer
# Mercedes-Benz           4599
# Vauxhall                3529
# Volkswagen              3272
# BMW                     2622
# Ford                    2553
# Audi                    2455
# Renault                 1484
# Volvo                   1472
# Peugeot                 1429
# Skoda                   1231
# Honda                    975
# Citroen                  929
# Saab                     825
# Toyota                   718
# Kia                      661
# Seat                     617
# Nissan                   586
# Fiat                     582
# Mitsubishi               578
# Hyundai                  551
# Mazda                    497
# Porsche                  493
# Chrysler Jeep            452
# Suzuki                   420
# Subaru                   414
# Chevrolet                383
# Alfa Romeo               379
# Mini                     359
# Jaguar Cars              321
# MG Rover Group           295
# Smart                    248
# ...

# %%
frequency = df4['manufacturer'].value_counts()

threshold = 50

low_frequency_categories = frequency[frequency < threshold].index

df['manufacturer'] = df4['manufacturer'].replace(low_frequency_categories, 'Other')

# %%
df4.drop('manufacturer_grouped', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df4.drop('manufacturer_grouped', axis = 1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# ...

# %%
df4.manufacturer.value_counts()
# Out:
# manufacturer
# Mercedes-Benz           4599
# Vauxhall                3529
# Volkswagen              3272
# BMW                     2622
# Ford                    2553
# Audi                    2455
# Renault                 1484
# Volvo                   1472
# Peugeot                 1429
# Skoda                   1231
# Honda                    975
# Citroen                  929
# Saab                     825
# Toyota                   718
# Kia                      661
# Seat                     617
# Nissan                   586
# Fiat                     582
# Mitsubishi               578
# Hyundai                  551
# Mazda                    497
# Porsche                  493
# Chrysler Jeep            452
# Suzuki                   420
# Subaru                   414
# Chevrolet                383
# Alfa Romeo               379
# Mini                     359
# Jaguar Cars              321
# MG Rover Group           295
# Smart                    248
# ...

# %%
df4.drop('manufacturer_grouped', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df4.drop('manufacturer_grouped', axis = 1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# ...

# %%
df4.manufacturer.value_counts()
# Out:
# manufacturer
# Mercedes-Benz           4599
# Vauxhall                3529
# Volkswagen              3272
# BMW                     2622
# Ford                    2553
# Audi                    2455
# Renault                 1484
# Volvo                   1472
# Peugeot                 1429
# Skoda                   1231
# Honda                    975
# Citroen                  929
# Saab                     825
# Toyota                   718
# Kia                      661
# Seat                     617
# Nissan                   586
# Fiat                     582
# Mitsubishi               578
# Hyundai                  551
# Mazda                    497
# Porsche                  493
# Chrysler Jeep            452
# Suzuki                   420
# Subaru                   414
# Chevrolet                383
# Alfa Romeo               379
# Mini                     359
# Jaguar Cars              321
# MG Rover Group           295
# Smart                    248
# ...

# %%
Y = df4.co2

# %%
Y
# Out:
# 65       146
# 66       186
# 82       219
# 83       243
# 97       183
#         ...
# 45506    122
# 45507    139
# 45508    139
# 45509    148
# 45510    149
# Name: co2, Length: 37246, dtype: int64

# %%
X = df4.drop(['model', 'co2'], axis = 1)

# %%
X
# Out:
#        year manufacturer transmission_type  engine_capacity  co_emissions  \
# 65     2000         Audi            Manual           1896.0         180.0
# 66     2000         Audi         Automatic           1896.0         220.0
# 82     2000         Audi            Manual           2496.0           4.0
# 83     2000         Audi         Automatic           2496.0         117.0
# 97     2000          BMW            Manual           1895.0         722.0
# ...     ...          ...               ...              ...           ...
# 45506  2013   Volkswagen            Manual           1968.0         165.0
# 45507  2013   Volkswagen            Manual           1984.0         409.0
# 45508  2013   Volkswagen            Manual           1984.0         409.0
# 45509  2013   Volkswagen            Manual           1984.0         357.0
# 45510  2013   Volkswagen            Manual           1984.0         357.0
#
#        nox_emissions  Diesel  Diesel Electric  Electricity/Diesel  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 100)

# %%
x_train
# Out:
#        year   manufacturer transmission_type  engine_capacity  co_emissions  \
# 15728  2005     Volkswagen            Manual           1896.0         131.0
# 27182  2009            Kia            Manual           1582.0         338.0
# 23311  2008           Ford            Manual           1753.0         557.0
# 42161  2013           Fiat            Manual           1956.0         225.0
# 548    2000          Honda            Manual           1997.0         642.0
# ...     ...            ...               ...              ...           ...
# 24197  2008         Nissan            Manual           1995.0         359.0
# 23716  2008  Mercedes-Benz            Manual           1992.0         339.0
# 440    2000           Ford            Manual           1988.0         710.0
# 19245  2006     Volkswagen            Manual           1390.0         370.0
# 21438  2007           Saab            Manual           1910.0         201.0
#
# ...

# %%
x_test
# Out:
#        year manufacturer transmission_type  engine_capacity  co_emissions  \
# 29306  2009   Volkswagen         Automatic           1968.0          63.0
# 8246   2003        Smart         Automatic            698.0         400.0
# 28145  2009      Renault         Automatic           3495.0         397.0
# 34017  2011         Audi         Automatic           1984.0         263.0
# 38463  2012      Citroen            Manual           1997.0         336.0
# ...     ...          ...               ...              ...           ...
# 14156  2005      Peugeot            Manual           1997.0          20.0
# 26120  2009          BMW         Automatic           1995.0         465.2
# 15962  2006         Audi         Automatic           1984.0         179.0
# 25870  2009         Audi         Automatic           1984.0         720.5
# 18305  2006      Renault            Manual           1461.0         179.0
#
#        nox_emissions  Diesel  Diesel Electric  Electricity/Diesel  \
# ...

# %%
from category_encoders import TargetEncoder
te = TargetEncoder()
te.fit(X = df.manufacturer, y = df['nox_emissions'])
values = te.transform(df.manufacturer)
df7 = df4
df7 = pd.concat([df7, values], axis = 1)
df7.head()
# Out:
#       year  manufacturer                              model transmission_type  \
# 65  2000.0          Audi       Audi A4 (Saloon, Avant & SE)            Manual
# 66  2000.0          Audi       Audi A4 (Saloon, Avant & SE)         Automatic
# 82  2000.0          Audi  Audi A6 (Saloon, Avant & Quattro)            Manual
# 83  2000.0          Audi  Audi A6 (Saloon, Avant & Quattro)         Automatic
# 97  2000.0           BMW                       3 Series E36            Manual
#
#     engine_capacity    co2  co_emissions  nox_emissions  Diesel  \
# 65           1896.0  146.0         180.0          430.0     1.0
# 66           1896.0  186.0         220.0          470.0     1.0
# 82           2496.0  219.0           4.0          318.0     1.0
# 83           2496.0  243.0         117.0          343.0     1.0
# 97           1895.0  183.0         722.0           47.0     0.0
#
#     Diesel Electric  Electricity/Diesel  Electricity/Petrol  LPG  \
# ...

# %%
# !pip install category_encoders

# %%
df7
# Out:
#          year  manufacturer                              model  \
# 65     2000.0          Audi       Audi A4 (Saloon, Avant & SE)
# 66     2000.0          Audi       Audi A4 (Saloon, Avant & SE)
# 82     2000.0          Audi  Audi A6 (Saloon, Avant & Quattro)
# 83     2000.0          Audi  Audi A6 (Saloon, Avant & Quattro)
# 97     2000.0           BMW                       3 Series E36
# ...       ...           ...                                ...
# 45454     NaN           NaN                                NaN
# 45493     NaN           NaN                                NaN
# 45494     NaN           NaN                                NaN
# 45495     NaN           NaN                                NaN
# 45496     NaN           NaN                                NaN
#
#       transmission_type  engine_capacity    co2  co_emissions  nox_emissions  \
# 65               Manual           1896.0  146.0         180.0          430.0
# ...

# %%
x_train1 = x_train

# %%
from category_encoders import TargetEncoder
te = TargetEncoder()
te.fit(X = x_train.manufacturer, y = x_train['nox_emissions'])
values = te.transform(x_train.manufacturer)
x_train = pd.concat([x_train, values], axis = 1)
x_train.head()
# Out:
#        year  manufacturer transmission_type  engine_capacity  co_emissions  \
# 15728  2005    Volkswagen            Manual           1896.0         131.0
# 27182  2009           Kia            Manual           1582.0         338.0
# 23311  2008          Ford            Manual           1753.0         557.0
# 42161  2013          Fiat            Manual           1956.0         225.0
# 548    2000         Honda            Manual           1997.0         642.0
#
#        nox_emissions  Diesel  Diesel Electric  Electricity/Diesel  \
# 15728          464.0       1                0                   0
# 27182          206.0       1                0                   0
# 23311          247.0       1                0                   0
# 42161          177.0       1                0                   0
# 548             39.0       0                0                   0
#
#        Electricity/Petrol  LPG  LPG / Petrol  Petrol  Petrol / E85  \
# ...

# %%
x_train.drop(df.columns[2], axis = 1)
# Out:
#        year transmission_type  engine_capacity  co_emissions  nox_emissions  \
# 15728  2005            Manual           1896.0         131.0          464.0
# 27182  2009            Manual           1582.0         338.0          206.0
# 23311  2008            Manual           1753.0         557.0          247.0
# 42161  2013            Manual           1956.0         225.0          177.0
# 548    2000            Manual           1997.0         642.0           39.0
# ...     ...               ...              ...           ...            ...
# 24197  2008            Manual           1995.0         359.0          131.0
# 23716  2008            Manual           1992.0         339.0          196.0
# 440    2000            Manual           1988.0         710.0           53.0
# 19245  2006            Manual           1390.0         370.0           38.0
# 21438  2007            Manual           1910.0         201.0          175.0
#
# ...

# %%
x_train
# Out:
#        year   manufacturer transmission_type  engine_capacity  co_emissions  \
# 15728  2005     Volkswagen            Manual           1896.0         131.0
# 27182  2009            Kia            Manual           1582.0         338.0
# 23311  2008           Ford            Manual           1753.0         557.0
# 42161  2013           Fiat            Manual           1956.0         225.0
# 548    2000          Honda            Manual           1997.0         642.0
# ...     ...            ...               ...              ...           ...
# 24197  2008         Nissan            Manual           1995.0         359.0
# 23716  2008  Mercedes-Benz            Manual           1992.0         339.0
# 440    2000           Ford            Manual           1988.0         710.0
# 19245  2006     Volkswagen            Manual           1390.0         370.0
# 21438  2007           Saab            Manual           1910.0         201.0
#
# ...

# %%
x_train.drop(df.columns[2], axis = 1)
# Out:
#        year transmission_type  engine_capacity  co_emissions  nox_emissions  \
# 15728  2005            Manual           1896.0         131.0          464.0
# 27182  2009            Manual           1582.0         338.0          206.0
# 23311  2008            Manual           1753.0         557.0          247.0
# 42161  2013            Manual           1956.0         225.0          177.0
# 548    2000            Manual           1997.0         642.0           39.0
# ...     ...               ...              ...           ...            ...
# 24197  2008            Manual           1995.0         359.0          131.0
# 23716  2008            Manual           1992.0         339.0          196.0
# 440    2000            Manual           1988.0         710.0           53.0
# 19245  2006            Manual           1390.0         370.0           38.0
# 21438  2007            Manual           1910.0         201.0          175.0
#
# ...

# %%
x_train
# Out:
#        year   manufacturer transmission_type  engine_capacity  co_emissions  \
# 15728  2005     Volkswagen            Manual           1896.0         131.0
# 27182  2009            Kia            Manual           1582.0         338.0
# 23311  2008           Ford            Manual           1753.0         557.0
# 42161  2013           Fiat            Manual           1956.0         225.0
# 548    2000          Honda            Manual           1997.0         642.0
# ...     ...            ...               ...              ...           ...
# 24197  2008         Nissan            Manual           1995.0         359.0
# 23716  2008  Mercedes-Benz            Manual           1992.0         339.0
# 440    2000           Ford            Manual           1988.0         710.0
# 19245  2006     Volkswagen            Manual           1390.0         370.0
# 21438  2007           Saab            Manual           1910.0         201.0
#
# ...

# %%
x_train = x_train.drop(x_train.columns[2], axis = 1)

# %%
x_train
# Out:
#        year   manufacturer  engine_capacity  co_emissions  nox_emissions  \
# 15728  2005     Volkswagen           1896.0         131.0          464.0
# 27182  2009            Kia           1582.0         338.0          206.0
# 23311  2008           Ford           1753.0         557.0          247.0
# 42161  2013           Fiat           1956.0         225.0          177.0
# 548    2000          Honda           1997.0         642.0           39.0
# ...     ...            ...              ...           ...            ...
# 24197  2008         Nissan           1995.0         359.0          131.0
# 23716  2008  Mercedes-Benz           1992.0         339.0          196.0
# 440    2000           Ford           1988.0         710.0           53.0
# 19245  2006     Volkswagen           1390.0         370.0           38.0
# 21438  2007           Saab           1910.0         201.0          175.0
#
#        Diesel  Diesel Electric  Electricity/Diesel  Electricity/Petrol  LPG  \
# ...

# %%
x_train
# Out:
#        year   manufacturer  engine_capacity  co_emissions  nox_emissions  \
# 15728  2005     Volkswagen           1896.0         131.0          464.0
# 27182  2009            Kia           1582.0         338.0          206.0
# 23311  2008           Ford           1753.0         557.0          247.0
# 42161  2013           Fiat           1956.0         225.0          177.0
# 548    2000          Honda           1997.0         642.0           39.0
# ...     ...            ...              ...           ...            ...
# 24197  2008         Nissan           1995.0         359.0          131.0
# 23716  2008  Mercedes-Benz           1992.0         339.0          196.0
# 440    2000           Ford           1988.0         710.0           53.0
# 19245  2006     Volkswagen           1390.0         370.0           38.0
# 21438  2007           Saab           1910.0         201.0          175.0
#
#        Diesel  Diesel Electric  Electricity/Diesel  Electricity/Petrol  LPG  \
# ...

# %%
x_train
# Out:
#        year   manufacturer  engine_capacity  co_emissions  nox_emissions  \
# 15728  2005     Volkswagen           1896.0         131.0          464.0
# 27182  2009            Kia           1582.0         338.0          206.0
# 23311  2008           Ford           1753.0         557.0          247.0
# 42161  2013           Fiat           1956.0         225.0          177.0
# 548    2000          Honda           1997.0         642.0           39.0
# ...     ...            ...              ...           ...            ...
# 24197  2008         Nissan           1995.0         359.0          131.0
# 23716  2008  Mercedes-Benz           1992.0         339.0          196.0
# 440    2000           Ford           1988.0         710.0           53.0
# 19245  2006     Volkswagen           1390.0         370.0           38.0
# 21438  2007           Saab           1910.0         201.0          175.0
#
#        Diesel  Diesel Electric  Electricity/Diesel  Electricity/Petrol  LPG  \
# ...

# %%
dummies = pd.get_dummies(df4['transmission_type'], dtype = int)
merged = pd.concat([df4, dummies], axis = 1)
df4 = merged.drop(['transmission_type','Automatic'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transmission_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 dummies = pd.get_dummies(df4['transmission_type'], dtype = int)
# ...

# %%
df4
# Out:
#        year manufacturer                              model  engine_capacity  \
# 65     2000         Audi       Audi A4 (Saloon, Avant & SE)           1896.0
# 66     2000         Audi       Audi A4 (Saloon, Avant & SE)           1896.0
# 82     2000         Audi  Audi A6 (Saloon, Avant & Quattro)           2496.0
# 83     2000         Audi  Audi A6 (Saloon, Avant & Quattro)           2496.0
# 97     2000          BMW                       3 Series E36           1895.0
# ...     ...          ...                                ...              ...
# 45506  2013   Volkswagen                      New Golf 2013           1968.0
# 45507  2013   Volkswagen                      New Golf 2013           1984.0
# 45508  2013   Volkswagen                      New Golf 2013           1984.0
# 45509  2013   Volkswagen                      New Golf 2013           1984.0
# 45510  2013   Volkswagen                      New Golf 2013           1984.0
#
# ...

# %%
X = df4.drop(['co2', 'model'], axis = 1)

# %%
X
# Out:
#        year manufacturer  engine_capacity  co_emissions  nox_emissions  \
# 65     2000         Audi           1896.0         180.0          430.0
# 66     2000         Audi           1896.0         220.0          470.0
# 82     2000         Audi           2496.0           4.0          318.0
# 83     2000         Audi           2496.0         117.0          343.0
# 97     2000          BMW           1895.0         722.0           47.0
# ...     ...          ...              ...           ...            ...
# 45506  2013   Volkswagen           1968.0         165.0           74.0
# 45507  2013   Volkswagen           1984.0         409.0           38.0
# 45508  2013   Volkswagen           1984.0         409.0           38.0
# 45509  2013   Volkswagen           1984.0         357.0           54.0
# 45510  2013   Volkswagen           1984.0         357.0           54.0
#
#        Diesel  Diesel Electric  Electricity/Diesel  Electricity/Petrol  LPG  \
# ...

# %%
y = df4.co2

# %%
y
# Out:
# 65       146
# 66       186
# 82       219
# 83       243
# 97       183
#         ...
# 45506    122
# 45507    139
# 45508    139
# 45509    148
# 45510    149
# Name: co2, Length: 37246, dtype: int64

# %%
X.shape
# Out:
# (37246, 17)

# %%
y.shape
# Out:
# (37246,)

# %%
from sklearn.model_selection import train_test_split
x_main, x_test, y_main, y_test = train_test_split(X, y, test_size = 0.2)
x_train, x_cv, y_train, y_val = train_test_split(x_main, y_main, test_size = 0.1)

# %%
from category_encoders import TargetEncoder
encoder = TargetEncoder(return_df = True, handle_missing = 'value', handle_unknown = 'value', min_samples_leaf = 20, smoothing = 10)

# %%
encoder.fit(x_train.manufacturer, x_train['co_emissions'])
# Out:
# TargetEncoder(cols=['manufacturer'])

# %%
x_train['manufacturer_encoded'] = encoder.transform(x_train.manufacturer, x_train['co_emissions'])

# %%
x_train
# Out:
#        year   manufacturer  engine_capacity  co_emissions  nox_emissions  \
# 18112  2006         Proton           1597.0         400.0           50.0
# 9851   2004          Honda           1396.0         400.0          100.0
# 14420  2005           Saab           2290.0         680.0           20.0
# 2027   2001        Citroen           1997.0         394.0           66.0
# 12445  2005            BMW           1995.0         320.0           39.0
# ...     ...            ...              ...           ...            ...
# 3947   2002           Audi           2496.0          66.0          273.0
# 34303  2011            BMW           1995.0         258.0          132.0
# 24304  2008        Peugeot           2946.0         760.0           13.0
# 25799  2009           Audi           1968.0          44.0          229.0
# 17365  2006  Mercedes-Benz           1796.0         453.0           27.0
#
#        Diesel  Diesel Electric  Electricity/Diesel  Electricity/Petrol  LPG  \
# ...

# %%
x_train.drop('manufacturer', axis = 1, inplace = True)

# %%
x_train
# Out:
#        year  engine_capacity  co_emissions  nox_emissions  Diesel  \
# 18112  2006           1597.0         400.0           50.0       0
# 9851   2004           1396.0         400.0          100.0       0
# 14420  2005           2290.0         680.0           20.0       0
# 2027   2001           1997.0         394.0           66.0       0
# 12445  2005           1995.0         320.0           39.0       0
# ...     ...              ...           ...            ...     ...
# 3947   2002           2496.0          66.0          273.0       1
# 34303  2011           1995.0         258.0          132.0       1
# 24304  2008           2946.0         760.0           13.0       0
# 25799  2009           1968.0          44.0          229.0       1
# 17365  2006           1796.0         453.0           27.0       0
#
#        Diesel Electric  Electricity/Diesel  Electricity/Petrol  LPG  \
# 18112                0                   0                   0    0
# ...

# %%
from sklearn.preprocessing import StandardScaler


numerical_columns = ['year', 'engine_capacity', 'nox_emissions'] 


scaler = StandardScaler()
scaler.fit(x_train[numerical_columns])


x_train[numerical_columns] = scaler.transform(x_train[numerical_columns])
x_cv[numerical_columns] = scaler.transform(x_cv[numerical_columns])
x_test[numerical_columns] = scaler.transform(x_test[numerical_columns])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
lr = LinearRegression()
linear_model = lr.fit(x_train, y_train)
linear_train_preds = linear_model.predict(x_train)
mean_absolute_error(linear_train_preds, y_train)
# Out:
# 16.81394235795964

# %%
x_train['manufacturer_encoded']
# Out:
# 38701    329.740675
# 32001    232.729419
# 20565    232.729419
# 24038    232.729419
# 22869    268.633962
#             ...
# 40797    250.384026
# 5081     343.150231
# 38729    329.740675
# 25705    357.612782
# 17159    232.729419
# Name: manufacturer_encoded, Length: 26816, dtype: float64

# %%
x_test['manufacturer_encoded'] = encoder.transform(x_test[['manufacturer']])

# %%
x_test.drop(columns=['manufacturer'], inplace=True)

# %%
x_test
# Out:
#            year  engine_capacity  co_emissions  nox_emissions  Diesel  \
# 37995  1.105739         1.431924         293.0      -0.628092       0
# 16902 -0.613039         0.225239         190.0       0.325424       1
# 43687  1.392202        -0.931621         143.0       0.066718       1
# 38904  1.105739        -1.032827         613.0      -0.901581       0
# 38176  1.105739         1.453722         428.0       0.318033       1
# ...         ...              ...           ...            ...     ...
# 15100 -0.899502        -0.718310         633.0      -0.598526       0
# 29981  0.532813        -0.100177         190.3       0.124373       1
# 27989  0.246350         1.028657          89.0       0.399340       1
# 32925  0.532813        -0.117304         179.0      -0.605917       0
# 13602 -0.899502         0.837145         144.0      -0.731575       0
#
#        Diesel Electric  Electricity/Diesel  Electricity/Petrol  LPG  \
# ...

# %%
x_cv['manufacturer_encoded'] = encoder.transform(x_cv[['manufacturer']])

# %%
x_cv.drop(columns=['manufacturer'], inplace=True)

# %%
x_cv
# Out:
#            year  engine_capacity  co_emissions  nox_emissions  Diesel  \
# 37851  1.105739         1.413239         234.0      -0.391561       1
# 30977  0.532813         1.413239         156.0      -0.709400       0
# 13902 -0.899502        -0.168685         218.0       2.143758       1
# 36912  0.819276        -1.650961         286.0      -0.857232       0
# 27805  0.246350        -0.740109         310.0      -0.835057       0
# ...         ...              ...           ...            ...     ...
# 24624 -0.040113        -0.232523          14.0       0.591522       1
# 31030  0.532813        -0.729209         535.0      -0.775924       0
# 40191  1.105739        -0.142216          83.0       0.251508       1
# 37395  0.819276        -0.142216         234.0       0.096285       1
# 18443 -0.613039        -0.117304         391.0      -0.835057       0
#
#        Diesel Electric  Electricity/Diesel  Electricity/Petrol  LPG  \
# ...

# %%
linear_test_preds = linear_model.predict(x_test)

# %%
mean_absolute_error(linear_test_preds, y_test)
# Out:
# 17.110995706825154

# %%
linear_train_preds = linear_model.predict(x_train)
mean_absolute_error(linear_train_preds, y_train)
# Out:
# 16.81394235795964

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators = 300, max_depth = 300).fit(x_train, y_train)
rf_train_preds = rf.predict(x_train)
rf_test_preds = rf.predict(x_test)
mean_absolute_error(rf_train_preds, y_train), mean_absolute_error(rf_test_preds, y_test)
# Out:
# (2.346657630251247, 4.598882267222357)

# %%
linear_val_preds = linear_model.predict(x_cv)

# %%
mean_absolute_error(y_val, linear_val_preds)
# Out:
# 16.74752089685167

# %%
rf_val_preds = rf.predict(x_cv)
mean_absolute_error(y_val, rf_val_preds)
# Out:
# 4.746154464312486

# %%
plt.figure(figsize = (5, 5))
plt.scatter(x = y_train, y = linear_train_preds, c = '#7CAE00', alpha = 0.3)

z = np.polyfit(y_train, linear_train_preds, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict Logs')
plt.xlabel('Experimental Logs')
# Out:
# Text(0.5, 0, 'Experimental Logs')

# %%
plt.figure(figsize = (5, 5))
plt.scatter(x = y_train, y = linear_train_preds, c = '#07fde1', alpha = 0.3)

z = np.polyfit(y_train, rf_train_preds, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#8a00d2')
plt.ylabel('Predict Logs')
plt.xlabel('Experimental Logs')
# Out:
# Text(0.5, 0, 'Experimental Logs')

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, linear_train_preds)
lr_train_r2 = r2_score(y_train, linear_train_preds)

lr_test_mse = mean_squared_error(y_test, linear_test_preds)
lr_test_r2 = r2_score(y_test, linear_test_preds)

# %%
lr_train_mse
# Out:
# 494.69172309291224

# %%
lr_train_r2
# Out:
# 0.7556999769435182

# %%
lr_test_mse
# Out:
# 509.4892126336984

# %%
lr_test_r2
# Out:
# 0.7430949201971606

# %%
lr_results = pd.DataFrame(['Linear Regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()

# %%
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2    Test MSE   Test R2
# 0  Linear Regression   494.691723      0.7557  509.489213  0.743095

# %%
rf_train_mse = mean_squared_error(y_train, rf_train_preds)
rf_train_r2 = r2_score(y_train, rf_train_preds)

rf_test_mse = mean_squared_error(y_test, rf_test_preds)
rf_test_r2 = r2_score(y_test, rf_test_preds)

# %%
rf_results = pd.DataFrame(['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()

# %%
rf_results
# Out:
#                0          1         2          3         4
# 0  Random Forest  13.673178  0.993248  58.196791  0.970655

# %%
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
rf_results
# Out:
#           Method Training MSE Training R2   Test MSE   Test R2
# 0  Random Forest    13.673178    0.993248  58.196791  0.970655

# %%
df_models = pd.concat([lr_results, rf_results], axis = 0).reset_index(drop = True)
df_models
# Out:
#               Method Training MSE Training R2    Test MSE   Test R2
# 0  Linear Regression   494.691723      0.7557  509.489213  0.743095
# 1      Random Forest    13.673178    0.993248   58.196791  0.970655

# %%
plt.figure(figsize = (5, 5))
plt.scatter(x = y_train, y = linear_train_preds, c = '#7CAE00', alpha = 0.3)

z = np.polyfit(y_train, linear_train_preds, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict Logs')
plt.xlabel('Experimental Logs')
plt.title('Using Linear Regression')
# Out:
# Text(0.5, 1.0, 'Using Linear Regression')

# %%
plt.figure(figsize = (5, 5))
plt.scatter(x = y_train, y = linear_train_preds, c = '#07fde1', alpha = 0.3)

z = np.polyfit(y_train, rf_train_preds, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#8a00d2')
plt.ylabel('Predict Logs')
plt.xlabel('Experimental Logs')
plt.title('Using Random Forest')
# Out:
# Text(0.5, 1.0, 'Using Random Forest')
